# %%
# Unit Conversion Program 

print("\033[1m Options:  \033[0m")

def options_list():  ## define a function called options_list
    
    print("[P] Print Options")   ## Prints an option list
    print("[C] Convert from Celsius")
    print("[F] Convert from Fahrenheit")
    print("[M] Convert from Miles")
    print("[KM] Convert from Kilometers")
    print("[IN] Convert from Inches")
    print("[CM] Convert from Centimeters")
    print("[Q] Quit" )

print(" ")

def c_f():
    celsius = float(input("Celsius: "))
    f = (celsius * 9/5) + 32
    print("Fahrenheit Temperature: ", f)
    
def f_c():
    fahrenheit = float(input("Fahrenheit: "))
    c = (fahrenheit - 32)/ 1.8
    print("Celsius Temperature: ", c)
 
def miles_km():
    miles = float(input("Miles: "))
    km = miles * 1.609
    print("Kilometers: ", km)
    
def km_miles():
    km = float(input("Kilometers: "))
    miles = km / 1.609
    print("Miles: ", miles) 
    
def in_cm():
    inches = float(input("Inches: "))
    cm = inches * 2.54
    print("Centimeters: ", cm)
    
def cm_in():
    cm = float(input("Centimeters: "))
    inches = cm * 0.39
    print("Inches: ", inches)
    
def quit():
    conversion = False
    

options_list()
  
option = str.upper(input("Option: "))

if option == "C":
    c_f()
elif option == "F":
    f_c()
elif option == "M":
    miles_km()
elif option == "KM":
    km_miles()
elif option == "IN":
    in_cm()
elif option == "CM":
    cm_in()
elif option == "Q":
    quit()
else:
    print("Invalid Entry")
# Out:
#  Options:
#
# [P] Print Options
# [C] Convert from Celsius
# [F] Convert from Fahrenheit
# [M] Convert from Miles
# [KM] Convert from Kilometers
# [IN] Convert from Inches
# [CM] Convert from Centimeters
# [Q] Quit
